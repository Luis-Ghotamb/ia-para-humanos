# %% [markdown]
# <a href="https://colab.research.google.com/github/Luis-Ghotamb/ia-para-humanos/blob/main/01_regressao_linear.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 📈 Regressão Linear - IA para Humanos
#
# > Vamos prever preços de casas com base em seu tamanho. Um exemplo clássico para entender como IA pode aprender padrões simples.

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
# Dados: tamanho da casa (m²) vs. preço (R$ mil)
X = np.array([50, 60, 70, 80, 90, 100, 110, 120]).reshape(-1, 1)
y = np.array([150, 180, 200, 210, 240, 250, 270, 290])

# %%
modelo = LinearRegression()
modelo.fit(X, y)

print(f"Coeficiente (m): {modelo.coef_[0]:.2f}")
print(f"Intercepto (b): {modelo.intercept_:.2f}")
# Out:
# Coeficiente (m): 1.92
# Intercepto (b): 60.83

# %%
plt.scatter(X, y, color='blue', label='Dados reais')
plt.plot(X, modelo.predict(X), color='red', label='Regressão Linear')
plt.title('Preço x Tamanho da Casa')
plt.xlabel('Tamanho (m²)')
plt.ylabel('Preço (R$ mil)')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## 🧠 Conclusão
#
# A regressão linear encontra a melhor **reta** que passa pelos dados, minimizando os erros entre o valor previsto e o valor real.
#
# O modelo aprendeu a fórmula:
# `preço = m * tamanho + b`
# Onde `m` é o coeficiente (inclinação da reta) e `b` é o intercepto (ponto onde a reta cruza o eixo Y).
